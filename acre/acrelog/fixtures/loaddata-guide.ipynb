# %% [markdown]
# This is a how to guide for importing data from .csv file to Django database (SQLite). You will see example data classes. Please note that those classes are for demonstration only. You are free to create classes in the way you see fit the best.
#
# The end goal is to create a JSON data that will be used to import data by Django built-in command. The format we want is structured as below. (more detail check -> https://docs.djangoproject.com/en/5.1/howto/initial-data/)
#
# ```JSON
# [
#   {
#     "model": "myapp.classname",
#     "pk": 1,
#     "fields": {
#       "attribute_name1": "Value",
#       "attribute_name2": "Value"
#     }
#   },
#   {
#     "model": "myapp.field",
#     "pk": 2,
#     "fields": {
#       "field_id": "32",
#       "field_name": "Corner"
#     }
#   }
# ]
#
# ```
#
# In Python, you can assume that JSON is Dictionary-like data type. So, the overall step is .csv -> Pandas dataframe -> dictionary ->JSON.
#
# Let's start with importing necessary modules. In this case, we only need 2 modules. Then load data from .csv to Pandas dataframe (we did this before in lab 2).

# %%
# import python's module
import pandas as pd
import json

# %%
# load data
log_df = pd.read_csv("operation-log.csv")  
log_df
# _df stands for data frame. It is a common suffix to indicate variable type.
# Out:
#            date operator location     operation  \
# 0     4/24/2022     Evan      200  Spread/Spray
# 1     4/27/2022    Bryan        6  Spread/Spray
# 2     4/27/2022    Bryan        5  Spread/Spray
# 3     4/27/2022    Bryan   Cotton  Spread/Spray
# 4     4/27/2022    Bryan      101  Spread/Spray
# ..          ...      ...      ...           ...
# 428  11/17/2022    Ceres      105  Spread/Spray
# 429  11/17/2022    Ceres      111  Spread/Spray
# 430  11/17/2022    Ceres       33  Spread/Spray
# 431  11/17/2022    Ceres       41  Spread/Spray
# 432  11/17/2022    Ceres        5  Spread/Spray
#
#                                             note   Power Unit Seeds planted  \
# 0                       2-4D round up burn down   Hagie STS12           NaN
# 1                                20oz ru, 11 24d  Hagie STS12           NaN
# 2                            20 oz ru/ 11 oz 24d  Hagie STS12           NaN
# 3                            20 oz ru. 11 oz 24d  Hagie STS12           NaN
# 4                             20 oz ru 11 oz 24d  Hagie STS12           NaN
# ..                                           ...          ...           ...
# 428  VRF MAP: 153 lbs/ac\nVRF Potash: 133 lbs/ac          NaN           NaN
# 429  VRF MAP: 139 lbs/ac\nVRF Potash: 121 lbs/ac          NaN           NaN
# 430                          VRF MAP: 154 lbs/ac          NaN           NaN
# 431                        VRF MAP: 115.8 lbs/ac          NaN           NaN
# 432          MAP: 240 lbs/ac\nPotash: 225 lbs/ac          NaN           NaN
#
#      Seeding Rate (seeds/ac)  Fertilizers applied  Fertilizer Rate (lb/ac)
# 0                        NaN                  NaN                      NaN
# 1                        NaN                  NaN                      NaN
# 2                        NaN                  NaN                      NaN
# 3                        NaN                  NaN                      NaN
# 4                        NaN                  NaN                      NaN
# ..                       ...                  ...                      ...
# 428                      NaN  MAP,Potash (0-0-60)                      NaN
# 429                      NaN  MAP,Potash (0-0-60)                      NaN
# 430                      NaN                  MAP                      NaN
# 431                      NaN                  MAP                      NaN
# 432                      NaN  MAP,Potash (0-0-60)                      NaN
#
# [433 rows x 10 columns]

# %% [markdown]
# First data class I want to create is Operator class ass below. As you can see that I created a class with attributes that we don't have data. That is okay, we can leave those attributes optional by adding `blank=True, null=True` (more detail here -> https://docs.djangoproject.com/en/5.1/ref/models/fields/#field-options).
#
# ```python
# class Operator(models.Model):
#     firstname = models.CharField(max_length=30)
#     lastname = models.CharField(max_length=30, blank=True, null=True)
#     middlename = models.CharField(max_length=30, blank=True, null=True)
#     phone = models.CharField(max_length=10, blank=True, null=True)
# ```
#
# You can think of a database class as a table. So, let's create an `Operator` table (dataframe). We will use Pandas' Unique fucntion to see how many operator rows we need to create. (more detail about unique function -> https://pandas.pydata.org/docs/reference/api/pandas.unique.html)

# %%
log_df['operator'].unique() # find a unique value in dataframe's `operator` column
# Out:
# array(['Evan', 'Bryan', 'Aaron', 'Rachel', 'Ceres'], dtype=object)

# %% [markdown]
# The result from unique function is an array which is iterable. We will iterate over the array and create a dataframe. There are several ways to create a dataframe. But I recommend doing by using a list of dict or a dict of list. I will show you the first case.

# %%
# create a list which we will add dictionaries later
operators = [] # suffix s is common way to indicate a list (array)
for person in log_df['operator'].unique(): # we iterate over the result from unique function
    operators.append( # append new element to the list
        { # curly bracket indicate the starting of dictionary
            "firstname": person, # each key-value pair
            "lastname": "",
            "phone": ""
        } # the end of dictionary
    )
operators # check the outcome
# Out:
# [{'firstname': 'Evan', 'lastname': '', 'phone': ''},
#  {'firstname': 'Bryan', 'lastname': '', 'phone': ''},
#  {'firstname': 'Aaron', 'lastname': '', 'phone': ''},
#  {'firstname': 'Rachel', 'lastname': '', 'phone': ''},
#  {'firstname': 'Ceres', 'lastname': '', 'phone': ''}]

# %% [markdown]
# Now we have a list of dictionaries. Making a dataframe is just one function. Note that I leave `lastname` and `phone` emtyp. This is an explicit way to work with optional attribute. You can also just ignore that attribute like I did with `middlename`. You will get the same outcome.

# %%
# create a dataframe
operator_df = pd.DataFrame(operators)
operator_df
# Out:
#   firstname lastname phone
# 0      Evan
# 1     Bryan
# 2     Aaron
# 3    Rachel
# 4     Ceres

# %% [markdown]
# The next step is to structure the data as required (check data format above). We will need to add `model` which is the class's name in the database. And `pk` or primary key which is the row's index. We want JSON at the end, but JSON is pretty much like dictionary in Python. So, we just need to create a (list of) dictionary.

# %%
operators = [] # create an empty list
for index, row in operator_df.iterrows(): # we iterate over the dataframe row by row
    operators.append( # append new element to the list
        { # curly bracket indicate the starting of dictionary
            "model": "acrelog.operator",  # the class name
            "pk": index+1, # index starts at 0 while primary key starts at 1. 
            "fields": { # this is a dictionary of attributes
                "firstname": row['firstname'] # only need firstname for now
            }
        } # the end of dictionary
    )
operators # see the result
# Out:
# [{'model': 'acrelog.operator', 'pk': 1, 'fields': {'firstname': 'Evan'}},
#  {'model': 'acrelog.operator', 'pk': 2, 'fields': {'firstname': 'Bryan'}},
#  {'model': 'acrelog.operator', 'pk': 3, 'fields': {'firstname': 'Aaron'}},
#  {'model': 'acrelog.operator', 'pk': 4, 'fields': {'firstname': 'Rachel'}},
#  {'model': 'acrelog.operator', 'pk': 5, 'fields': {'firstname': 'Ceres'}}]

# %% [markdown]
# Now we have the data in the format that we need. To convert into JSON, you can just run the following command. Then you can copy the result and check with https://jsonlint.com/

# %%
json.dumps(operators)
# Out:
# '[{"model": "acrelog.operator", "pk": 1, "fields": {"firstname": "Evan"}}, {"model": "acrelog.operator", "pk": 2, "fields": {"firstname": "Bryan"}}, {"model": "acrelog.operator", "pk": 3, "fields": {"firstname": "Aaron"}}, {"model": "acrelog.operator", "pk": 4, "fields": {"firstname": "Rachel"}}, {"model": "acrelog.operator", "pk": 5, "fields": {"firstname": "Ceres"}}]'

# %%
# or write the JSON to the file directly 
with open('operator-data.json', 'w') as fp:
    json.dump(operators, fp=fp, indent=4)

# %% [markdown]
# You might wonder why we create a dictionary then convert into a dataframe just for turn it into a dictionary again. Can you just make a dictionary that follows the required stucture directly? Absolutely yes. In some cases, that will be the better way to deal with the data. But there is a usecase for a dataframe as well. You will see it soon. For now, let's create another data class.
#
# ```python
# class Operation(models.Model):
#     date = models.DateField()
#     note = models.CharField(max_length=300, blank=True, null=True)
#     operator = models.ForeignKey(Operator, on_delete=models.CASCADE)
# ```
# In this class, it has a foreignkey that points to Operator class. So, instead of recording operator name, we will keep the primary key that points to that operator. For better understanding, I will trim the original dataframe to keep only the data that we will play with.

# %%
# you can subset the dataframe with any columns (and order)
sub_log_df = log_df[['date', 'operator', 'note']]
sub_log_df
# Out:
#            date operator                                         note
# 0     4/24/2022     Evan                     2-4D round up burn down
# 1     4/27/2022    Bryan                              20oz ru, 11 24d
# 2     4/27/2022    Bryan                          20 oz ru/ 11 oz 24d
# 3     4/27/2022    Bryan                          20 oz ru. 11 oz 24d
# 4     4/27/2022    Bryan                           20 oz ru 11 oz 24d
# ..          ...      ...                                          ...
# 428  11/17/2022    Ceres  VRF MAP: 153 lbs/ac\nVRF Potash: 133 lbs/ac
# 429  11/17/2022    Ceres  VRF MAP: 139 lbs/ac\nVRF Potash: 121 lbs/ac
# 430  11/17/2022    Ceres                          VRF MAP: 154 lbs/ac
# 431  11/17/2022    Ceres                        VRF MAP: 115.8 lbs/ac
# 432  11/17/2022    Ceres          MAP: 240 lbs/ac\nPotash: 225 lbs/ac
#
# [433 rows x 3 columns]

# %% [markdown]
# We will use the map function (more detail -> https://pandas.pydata.org/docs/reference/api/pandas.Series.map.html) to map from the operator's name to primary key. The map functions take several options. But we will use dictionary. The dictionary we want has operator's names as keys and primary keys as values. Do you feel that this structure looks familar. Yes, that is the operator dataframe that we created earlier.

# %%
operator_df
# Out:
#   firstname lastname phone
# 0      Evan
# 1     Bryan
# 2     Aaron
# 3    Rachel
# 4     Ceres

# %% [markdown]
# As I mentioned earlier, dataframe is made from a list of dictionaries or a dictionary of lists. We can convert it back as well.

# %%
operator_df.to_dict()
# Out:
# {'firstname': {0: 'Evan', 1: 'Bryan', 2: 'Aaron', 3: 'Rachel', 4: 'Ceres'},
#  'lastname': {0: '', 1: '', 2: '', 3: '', 4: ''},
#  'phone': {0: '', 1: '', 2: '', 3: '', 4: ''}}

# %% [markdown]
# The format you see above is a dictionary of list. We want to use firstname to map with primary key (or dataframe's index). So we will only care about the `firstname`.

# %%
operator_df.to_dict()['firstname']
# Out:
# {0: 'Evan', 1: 'Bryan', 2: 'Aaron', 3: 'Rachel', 4: 'Ceres'}

# %% [markdown]
# Almost done. We want a dictionary that keys are firstname and values are primary keys. But what we got is opposite. No problem, we just need to inverse it (and add 1 to pandas' index to make it become primary key)

# %%
index_name = operator_df.to_dict()['firstname']
name2pk = dict((v, k+1) for k, v in index_name.items())
name2pk
# Out:
# {'Evan': 1, 'Bryan': 2, 'Aaron': 3, 'Rachel': 4, 'Ceres': 5}

# %% [markdown]
# We got it. Now, let map the operator's name to primary key.

# %%
sub_log_df['operator'] = sub_log_df['operator'].map(name2pk) 
sub_log_df
# Out:
# /var/folders/_t/xf80sxmn3c99xrwsspdr3tc00000gp/T/ipykernel_27436/2883430231.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_log_df['operator'] = sub_log_df['operator'].map(name2pk)
#            date  operator                                         note
# 0     4/24/2022         1                     2-4D round up burn down
# 1     4/27/2022         2                              20oz ru, 11 24d
# 2     4/27/2022         2                          20 oz ru/ 11 oz 24d
# 3     4/27/2022         2                          20 oz ru. 11 oz 24d
# 4     4/27/2022         2                           20 oz ru 11 oz 24d
# ..          ...       ...                                          ...
# 428  11/17/2022         5  VRF MAP: 153 lbs/ac\nVRF Potash: 133 lbs/ac
# 429  11/17/2022         5  VRF MAP: 139 lbs/ac\nVRF Potash: 121 lbs/ac
# 430  11/17/2022         5                          VRF MAP: 154 lbs/ac
# 431  11/17/2022         5                        VRF MAP: 115.8 lbs/ac
# 432  11/17/2022         5          MAP: 240 lbs/ac\nPotash: 225 lbs/ac
#
# [433 rows x 3 columns]

# %% [markdown]
# Before we make the final dictionary, we need to deal with date format. Django's SQLite expects `YYYY-MM-DD` format. So, we need to fix our date column a little bit. What you see is only string (a series of charactor). Python has a date (or datetime) variable for dealing with this type of data. Date data type is numerial. So, we can do calulation and also, in our case, format in the way we want. First, we need to convert string to datetime.

# %%
pd.to_datetime(sub_log_df['date'])
# Out:
# 0     2022-04-24
# 1     2022-04-27
# 2     2022-04-27
# 3     2022-04-27
# 4     2022-04-27
#          ...
# 428   2022-11-17
# 429   2022-11-17
# 430   2022-11-17
# 431   2022-11-17
# 432   2022-11-17
# Name: date, Length: 433, dtype: datetime64[ns]

# %% [markdown]
# As you can see, we have a date column which we can do many thing on it. But we will just convert it back into string (with the format that we want). Then we will make a dictionary and JSON. The function we use is `strftime` (string from time).

# %%
sub_log_df['date'] = pd.to_datetime(sub_log_df['date']).dt.strftime('%Y-%m-%d')
sub_log_df
# Out:
# /var/folders/_t/xf80sxmn3c99xrwsspdr3tc00000gp/T/ipykernel_27436/2137056224.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_log_df['date'] = pd.to_datetime(sub_log_df['date']).dt.strftime('%Y-%m-%d')
#            date  operator                                         note
# 0    2022-04-24         1                     2-4D round up burn down
# 1    2022-04-27         2                              20oz ru, 11 24d
# 2    2022-04-27         2                          20 oz ru/ 11 oz 24d
# 3    2022-04-27         2                          20 oz ru. 11 oz 24d
# 4    2022-04-27         2                           20 oz ru 11 oz 24d
# ..          ...       ...                                          ...
# 428  2022-11-17         5  VRF MAP: 153 lbs/ac\nVRF Potash: 133 lbs/ac
# 429  2022-11-17         5  VRF MAP: 139 lbs/ac\nVRF Potash: 121 lbs/ac
# 430  2022-11-17         5                          VRF MAP: 154 lbs/ac
# 431  2022-11-17         5                        VRF MAP: 115.8 lbs/ac
# 432  2022-11-17         5          MAP: 240 lbs/ac\nPotash: 225 lbs/ac
#
# [433 rows x 3 columns]

# %% [markdown]
# Now, we have everything ready. Let's create the final dictionary.

# %%
logs = []
for index, row in sub_log_df.iterrows():
    logs.append({
        "model": "acrelog.operation", 
        "pk": index+1,
        "fields": {
            "date": row['date'],
            "operator": row['operator'],
            "note": row['note'],
        }
    })
logs
# Out:
# [{'model': 'acrelog.operation',
#   'pk': 1,
#   'fields': {'date': '2022-04-24',
#    'operator': 1,
#    'note': '2-4D round up burn down '}},
#  {'model': 'acrelog.operation',
#   'pk': 2,
#   'fields': {'date': '2022-04-27', 'operator': 2, 'note': '20oz ru, 11 24d'}},
#  {'model': 'acrelog.operation',
#   'pk': 3,
#   'fields': {'date': '2022-04-27',
#    'operator': 2,
#    'note': '20 oz ru/ 11 oz 24d'}},
#  {'model': 'acrelog.operation',
#   'pk': 4,
#   'fields': {'date': '2022-04-27',
#    'operator': 2,
#    'note': '20 oz ru. 11 oz 24d'}},
#  {'model': 'acrelog.operation',
#   'pk': 5,
#   'fields': {'date': '2022-04-27',
#    'operator': 2,
#    'note': '20 oz ru 11 oz 24d'}},
#  {'model': 'acrelog.operation',
#   'pk': 6,
#   'fields': {'date': '2022-04-27', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 7,
#   'fields': {'date': '2022-04-27', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 8,
#   'fields': {'date': '2022-04-27', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 9,
#   'fields': {'date': '2022-04-27', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 10,
#   'fields': {'date': '2022-04-28', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 11,
#   'fields': {'date': '2022-04-27', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 12,
#   'fields': {'date': '2022-04-27', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 13,
#   'fields': {'date': '2022-04-27', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 14,
#   'fields': {'date': '2022-04-27', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 15,
#   'fields': {'date': '2022-04-27',
#    'operator': 3,
#    'note': 'JD FC & Rolling Basket '}},
#  {'model': 'acrelog.operation',
#   'pk': 16,
#   'fields': {'date': '2022-04-27',
#    'operator': 3,
#    'note': 'JD FC & Rolling Basket '}},
#  {'model': 'acrelog.operation',
#   'pk': 17,
#   'fields': {'date': '2022-04-27',
#    'operator': 2,
#    'note': '20 gal 28, 1.5 qt bicep, .75 qt atz, 12 oz instinct'}},
#  {'model': 'acrelog.operation',
#   'pk': 18,
#   'fields': {'date': '2022-04-27',
#    'operator': 2,
#    'note': '20 gal 28, 1.5 qt bicep, .75 qt atz, 12 oz instinct.   Minus quinn on the East end'}},
#  {'model': 'acrelog.operation',
#   'pk': 19,
#   'fields': {'date': '2022-04-27',
#    'operator': 2,
#    'note': '20 gal 28, 1.75 qt bicep, .75 qt atz, 12 oz instinct.  Minus guri plot East end'}},
#  {'model': 'acrelog.operation',
#   'pk': 20,
#   'fields': {'date': '2022-04-27',
#    'operator': 2,
#    'note': '20 gal 28, 1.75 qt bicep, .75 qt atz, 12 oz instinct '}},
#  {'model': 'acrelog.operation',
#   'pk': 21,
#   'fields': {'date': '2022-04-27',
#    'operator': 2,
#    'note': '20 gal 28, 1.75 qt bicep, .75 qt atz, 12 oz instinct '}},
#  {'model': 'acrelog.operation',
#   'pk': 22,
#   'fields': {'date': '2022-04-27',
#    'operator': 2,
#    'note': '20 gal 28, 1.75 qt bicep, .75 qt atz, 12 oz instinct '}},
#  {'model': 'acrelog.operation',
#   'pk': 23,
#   'fields': {'date': '2022-04-27',
#    'operator': 2,
#    'note': '20 gal 28, 1.75 qt bicep, .75 qt atz, 12 oz instinct '}},
#  {'model': 'acrelog.operation',
#   'pk': 24,
#   'fields': {'date': '2022-04-27',
#    'operator': 2,
#    'note': '20 gal 28, 1.75 qt bicep, .75 atz, 12 oz instinct '}},
#  {'model': 'acrelog.operation',
#   'pk': 25,
#   'fields': {'date': '2022-04-27',
#    'operator': 2,
#    'note': '20 gal 28, 1.75 qt bicep, .75 qt atz, 12 oz instinct '}},
#  {'model': 'acrelog.operation',
#   'pk': 26,
#   'fields': {'date': '2022-04-27',
#    'operator': 2,
#    'note': '20 gal 28, 1.75 qt bicep, .75 qt Atz, 12 oz instinct '}},
#  {'model': 'acrelog.operation',
#   'pk': 27,
#   'fields': {'date': '2022-04-28', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 28,
#   'fields': {'date': '2022-04-28', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 29,
#   'fields': {'date': '2022-04-28', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 30,
#   'fields': {'date': '2022-04-28', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 31,
#   'fields': {'date': '2022-04-28', 'operator': 3, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 32,
#   'fields': {'date': '2022-04-28', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 33,
#   'fields': {'date': '2022-04-28', 'operator': 3, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 34,
#   'fields': {'date': '2022-04-28', 'operator': 2, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 35,
#   'fields': {'date': '2022-04-28', 'operator': 2, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 36,
#   'fields': {'date': '2022-04-28', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 37,
#   'fields': {'date': '2022-04-28', 'operator': 3, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 38,
#   'fields': {'date': '2022-04-28',
#    'operator': 2,
#    'note': 'Lots of chickweed residue, fairly rough '}},
#  {'model': 'acrelog.operation',
#   'pk': 39,
#   'fields': {'date': '2022-04-28', 'operator': 2, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 40,
#   'fields': {'date': '2022-04-28', 'operator': 2, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 41,
#   'fields': {'date': '2022-04-28',
#    'operator': 1,
#    'note': 'Round up 2-4D valor'}},
#  {'model': 'acrelog.operation',
#   'pk': 42,
#   'fields': {'date': '2022-04-28',
#    'operator': 1,
#    'note': 'Round up 2-4D valor'}},
#  {'model': 'acrelog.operation',
#   'pk': 43,
#   'fields': {'date': '2022-04-28',
#    'operator': 1,
#    'note': 'Round up 2-4D valor'}},
#  {'model': 'acrelog.operation',
#   'pk': 44,
#   'fields': {'date': '2022-04-28',
#    'operator': 1,
#    'note': 'Round up 2-4D valor'}},
#  {'model': 'acrelog.operation',
#   'pk': 45,
#   'fields': {'date': '2022-04-28',
#    'operator': 1,
#    'note': 'Round up 2-4D valor'}},
#  {'model': 'acrelog.operation',
#   'pk': 46,
#   'fields': {'date': '2022-04-29',
#    'operator': 1,
#    'note': 'Planted on 4 degree angle'}},
#  {'model': 'acrelog.operation',
#   'pk': 47,
#   'fields': {'date': '2022-04-29', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 48,
#   'fields': {'date': '2022-04-29', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 49,
#   'fields': {'date': '2022-04-29', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 50,
#   'fields': {'date': '2022-04-29', 'operator': 2, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 51,
#   'fields': {'date': '2022-04-29', 'operator': 2, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 52,
#   'fields': {'date': '2022-04-29', 'operator': 2, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 53,
#   'fields': {'date': '2022-04-29', 'operator': 2, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 54,
#   'fields': {'date': '2022-04-29', 'operator': 2, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 55,
#   'fields': {'date': '2022-04-29', 'operator': 2, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 56,
#   'fields': {'date': '2022-04-29', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 57,
#   'fields': {'date': '2022-04-29', 'operator': 3, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 58,
#   'fields': {'date': '2022-04-29', 'operator': 3, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 59,
#   'fields': {'date': '2022-04-29',
#    'operator': 3,
#    'note': 'Soy Pre. 3oz valor&32oz rd up'}},
#  {'model': 'acrelog.operation',
#   'pk': 60,
#   'fields': {'date': '2022-04-29', 'operator': 4, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 61,
#   'fields': {'date': '2022-04-29', 'operator': 4, 'note': 'Fc'}},
#  {'model': 'acrelog.operation',
#   'pk': 62,
#   'fields': {'date': '2022-04-29', 'operator': 4, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 63,
#   'fields': {'date': '2022-04-29', 'operator': 4, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 64,
#   'fields': {'date': '2022-04-29', 'operator': 3, 'note': 'Valor XLT'}},
#  {'model': 'acrelog.operation',
#   'pk': 65,
#   'fields': {'date': '2022-04-29', 'operator': 4, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 66,
#   'fields': {'date': '2022-04-29', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 67,
#   'fields': {'date': '2022-04-29', 'operator': 3, 'note': 'Valor XLT'}},
#  {'model': 'acrelog.operation',
#   'pk': 68,
#   'fields': {'date': '2022-04-29', 'operator': 3, 'note': 'Valor XLT'}},
#  {'model': 'acrelog.operation',
#   'pk': 69,
#   'fields': {'date': '2022-04-29', 'operator': 3, 'note': 'Valor XLT'}},
#  {'model': 'acrelog.operation',
#   'pk': 70,
#   'fields': {'date': '2022-04-29', 'operator': 3, 'note': 'Valor XLT'}},
#  {'model': 'acrelog.operation',
#   'pk': 71,
#   'fields': {'date': '2022-04-29', 'operator': 3, 'note': 'Valor XLT'}},
#  {'model': 'acrelog.operation',
#   'pk': 72,
#   'fields': {'date': '2022-04-29', 'operator': 4, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 73,
#   'fields': {'date': '2022-04-29', 'operator': 4, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 74,
#   'fields': {'date': '2022-04-29', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 75,
#   'fields': {'date': '2022-04-29', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 76,
#   'fields': {'date': '2022-04-29', 'operator': 2, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 77,
#   'fields': {'date': '2022-04-29', 'operator': 2, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 78,
#   'fields': {'date': '2022-04-30', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 79,
#   'fields': {'date': '2022-04-30', 'operator': 3, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 80,
#   'fields': {'date': '2022-04-30', 'operator': 3, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 81,
#   'fields': {'date': '2022-04-30', 'operator': 3, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 82,
#   'fields': {'date': '2022-04-30', 'operator': 3, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 83,
#   'fields': {'date': '2022-04-30', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 84,
#   'fields': {'date': '2022-04-30', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 85,
#   'fields': {'date': '2022-04-30', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 86,
#   'fields': {'date': '2022-04-30', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 87,
#   'fields': {'date': '2022-04-30', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 88,
#   'fields': {'date': '2022-04-30', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 89,
#   'fields': {'date': '2022-04-29', 'operator': 4, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 90,
#   'fields': {'date': '2022-04-29', 'operator': 4, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 91,
#   'fields': {'date': '2022-04-30', 'operator': 3, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 92,
#   'fields': {'date': '2022-04-30', 'operator': 3, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 93,
#   'fields': {'date': '2022-04-30', 'operator': 3, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 94,
#   'fields': {'date': '2022-04-30', 'operator': 3, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 95,
#   'fields': {'date': '2022-04-30', 'operator': 3, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 96,
#   'fields': {'date': '2022-04-30', 'operator': 1, 'note': 'Valor'}},
#  {'model': 'acrelog.operation',
#   'pk': 97,
#   'fields': {'date': '2022-04-30', 'operator': 1, 'note': 'Valor'}},
#  {'model': 'acrelog.operation',
#   'pk': 98,
#   'fields': {'date': '2022-04-30', 'operator': 1, 'note': 'Valor'}},
#  {'model': 'acrelog.operation',
#   'pk': 99,
#   'fields': {'date': '2022-04-30', 'operator': 1, 'note': 'Valor'}},
#  {'model': 'acrelog.operation',
#   'pk': 100,
#   'fields': {'date': '2022-04-30', 'operator': 1, 'note': 'Valor'}},
#  {'model': 'acrelog.operation',
#   'pk': 101,
#   'fields': {'date': '2022-04-30', 'operator': 1, 'note': 'Valor'}},
#  {'model': 'acrelog.operation',
#   'pk': 102,
#   'fields': {'date': '2022-04-30', 'operator': 1, 'note': 'Valor'}},
#  {'model': 'acrelog.operation',
#   'pk': 103,
#   'fields': {'date': '2022-04-30', 'operator': 1, 'note': 'Valor'}},
#  {'model': 'acrelog.operation',
#   'pk': 104,
#   'fields': {'date': '2022-04-30', 'operator': 1, 'note': 'Valor'}},
#  {'model': 'acrelog.operation',
#   'pk': 105,
#   'fields': {'date': '2022-04-30', 'operator': 1, 'note': 'Valor'}},
#  {'model': 'acrelog.operation',
#   'pk': 106,
#   'fields': {'date': '2022-04-30', 'operator': 1, 'note': 'Valor'}},
#  {'model': 'acrelog.operation',
#   'pk': 107,
#   'fields': {'date': '2022-04-28', 'operator': 3, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 108,
#   'fields': {'date': '2022-04-30', 'operator': 2, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 109,
#   'fields': {'date': '2022-04-30', 'operator': 2, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 110,
#   'fields': {'date': '2022-04-30', 'operator': 2, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 111,
#   'fields': {'date': '2022-04-30', 'operator': 2, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 112,
#   'fields': {'date': '2022-04-30', 'operator': 2, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 113,
#   'fields': {'date': '2022-04-30', 'operator': 2, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 114,
#   'fields': {'date': '2022-04-30', 'operator': 2, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 115,
#   'fields': {'date': '2022-04-30', 'operator': 2, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 116,
#   'fields': {'date': '2022-04-30', 'operator': 2, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 117,
#   'fields': {'date': '2022-05-02', 'operator': 3, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 118,
#   'fields': {'date': '2022-05-02', 'operator': 3, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 119,
#   'fields': {'date': '2022-05-02', 'operator': 3, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 120,
#   'fields': {'date': '2022-05-02', 'operator': 4, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 121,
#   'fields': {'date': '2022-05-02', 'operator': 4, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 122,
#   'fields': {'date': '2022-05-02', 'operator': 4, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 123,
#   'fields': {'date': '2022-05-02', 'operator': 4, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 124,
#   'fields': {'date': '2022-05-02', 'operator': 2, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 125,
#   'fields': {'date': '2022-05-02', 'operator': 2, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 126,
#   'fields': {'date': '2022-05-02', 'operator': 2, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 127,
#   'fields': {'date': '2022-05-02', 'operator': 2, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 128,
#   'fields': {'date': '2022-05-02',
#    'operator': 2,
#    'note': 'Sprayed west (partial) in op center under bicep '}},
#  {'model': 'acrelog.operation',
#   'pk': 129,
#   'fields': {'date': '2022-05-02', 'operator': 2, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 130,
#   'fields': {'date': '2022-05-02', 'operator': 2, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 131,
#   'fields': {'date': '2022-05-02', 'operator': 2, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 132,
#   'fields': {'date': '2022-05-02',
#    'operator': 2,
#    'note': 'Remaining area around plot 2 nd pass'}},
#  {'model': 'acrelog.operation',
#   'pk': 133,
#   'fields': {'date': '2022-05-02', 'operator': 2, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 134,
#   'fields': {'date': '2022-05-02', 'operator': 2, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 135,
#   'fields': {'date': '2022-05-02', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 136,
#   'fields': {'date': '2022-05-02', 'operator': 1, 'note': 'West side'}},
#  {'model': 'acrelog.operation',
#   'pk': 137,
#   'fields': {'date': '2022-05-10',
#    'operator': 3,
#    'note': 'Harmony on wheat plot '}},
#  {'model': 'acrelog.operation',
#   'pk': 138,
#   'fields': {'date': '2022-05-10',
#    'operator': 1,
#    'note': 'Sprayed 50gal on ISO’s both east and west ends'}},
#  {'model': 'acrelog.operation',
#   'pk': 139,
#   'fields': {'date': '2022-05-10',
#    'operator': 1,
#    'note': 'Sprayed iso on east end 50 gal'}},
#  {'model': 'acrelog.operation',
#   'pk': 140,
#   'fields': {'date': '2022-05-10',
#    'operator': 1,
#    'note': 'Sprayed 50 gal iso on east end'}},
#  {'model': 'acrelog.operation',
#   'pk': 141,
#   'fields': {'date': '2022-05-10', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 142,
#   'fields': {'date': '2022-05-10', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 143,
#   'fields': {'date': '2022-05-10', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 144,
#   'fields': {'date': '2022-05-10', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 145,
#   'fields': {'date': '2022-05-11', 'operator': 2, 'note': 'Roundup @30 oz. '}},
#  {'model': 'acrelog.operation',
#   'pk': 146,
#   'fields': {'date': '2022-05-11', 'operator': 2, 'note': '3oz valor'}},
#  {'model': 'acrelog.operation',
#   'pk': 147,
#   'fields': {'date': '2022-05-11', 'operator': 2, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 148,
#   'fields': {'date': '2022-05-11', 'operator': 2, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 149,
#   'fields': {'date': '2022-05-11', 'operator': 2, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 150,
#   'fields': {'date': '2022-05-11', 'operator': 2, 'note': 'P 1099q '}},
#  {'model': 'acrelog.operation',
#   'pk': 151,
#   'fields': {'date': '2022-05-11', 'operator': 2, 'note': 'P1099q'}},
#  {'model': 'acrelog.operation',
#   'pk': 152,
#   'fields': {'date': '2022-05-11',
#    'operator': 4,
#    'note': 'Disced former grass edges around field ahead of planting'}},
#  {'model': 'acrelog.operation',
#   'pk': 153,
#   'fields': {'date': '2022-05-11', 'operator': 4, 'note': 'West half'}},
#  {'model': 'acrelog.operation',
#   'pk': 154,
#   'fields': {'date': '2022-05-11', 'operator': 4, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 155,
#   'fields': {'date': '2022-05-11', 'operator': 3, 'note': 'West 65 acres'}},
#  {'model': 'acrelog.operation',
#   'pk': 156,
#   'fields': {'date': '2022-05-11', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 157,
#   'fields': {'date': '2022-05-11', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 158,
#   'fields': {'date': '2022-05-11', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 159,
#   'fields': {'date': '2022-05-11', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 160,
#   'fields': {'date': '2022-05-11', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 161,
#   'fields': {'date': '2022-05-11', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 162,
#   'fields': {'date': '2022-05-11', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 163,
#   'fields': {'date': '2022-05-12', 'operator': 2, 'note': 'Blank for ma'}},
#  {'model': 'acrelog.operation',
#   'pk': 164,
#   'fields': {'date': '2022-05-12',
#    'operator': 2,
#    'note': 'Last 45 acres (East) degree extra '}},
#  {'model': 'acrelog.operation',
#   'pk': 165,
#   'fields': {'date': '2022-05-12', 'operator': 2, 'note': 'Degree extra '}},
#  {'model': 'acrelog.operation',
#   'pk': 166,
#   'fields': {'date': '2022-05-12',
#    'operator': 4,
#    'note': 'Tillage before marking rows....rough'}},
#  {'model': 'acrelog.operation',
#   'pk': 167,
#   'fields': {'date': '2022-05-12',
#    'operator': 4,
#    'note': '3rd pass for wetland group'}},
#  {'model': 'acrelog.operation',
#   'pk': 168,
#   'fields': {'date': '2022-05-12', 'operator': 4, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 169,
#   'fields': {'date': '2022-05-12',
#    'operator': 4,
#    'note': 'Ran out along road and finished with two bags of 2.6 Pioneer leftover from Casteel.'}},
#  {'model': 'acrelog.operation',
#   'pk': 170,
#   'fields': {'date': '2022-05-13', 'operator': 3, 'note': 'Valor'}},
#  {'model': 'acrelog.operation',
#   'pk': 171,
#   'fields': {'date': '2022-05-14',
#    'operator': 2,
#    'note': '1108q, dk5835, p0720'}},
#  {'model': 'acrelog.operation',
#   'pk': 172,
#   'fields': {'date': '2022-05-14',
#    'operator': 3,
#    'note': 'Valor XLT usda plot '}},
#  {'model': 'acrelog.operation',
#   'pk': 173,
#   'fields': {'date': '2022-05-14',
#    'operator': 3,
#    'note': 'Valor XLT on Ma Plot east end\nValor XLT west end fill\n'}},
#  {'model': 'acrelog.operation',
#   'pk': 174,
#   'fields': {'date': '2022-05-14', 'operator': 3, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 175,
#   'fields': {'date': '2022-05-14', 'operator': 3, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 176,
#   'fields': {'date': '2022-05-13',
#    'operator': 1,
#    'note': 'Planted with 6 row. 33,000 pop. 13 gal 10-34-0 planted west to east'}},
#  {'model': 'acrelog.operation',
#   'pk': 177,
#   'fields': {'date': '2022-05-14', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 178,
#   'fields': {'date': '2022-05-14', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 179,
#   'fields': {'date': '2022-05-14', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 180,
#   'fields': {'date': '2022-05-14',
#    'operator': 1,
#    'note': 'Bulk fill sprayed '}},
#  {'model': 'acrelog.operation',
#   'pk': 181,
#   'fields': {'date': '2022-05-14', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 182,
#   'fields': {'date': '2022-05-14', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 183,
#   'fields': {'date': '2022-05-14', 'operator': 2, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 184,
#   'fields': {'date': '2022-05-14', 'operator': 2, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 185,
#   'fields': {'date': '2022-05-14', 'operator': 2, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 186,
#   'fields': {'date': '2022-05-14', 'operator': 2, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 187,
#   'fields': {'date': '2022-05-14', 'operator': 2, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 188,
#   'fields': {'date': '2022-05-14', 'operator': 4, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 189,
#   'fields': {'date': '2022-05-14', 'operator': 4, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 190,
#   'fields': {'date': '2022-05-14',
#    'operator': 4,
#    'note': 'About 1/3 done before rained out '}},
#  {'model': 'acrelog.operation',
#   'pk': 191,
#   'fields': {'date': '2022-05-24',
#    'operator': 3,
#    'note': 'Dual on soybean plots'}},
#  {'model': 'acrelog.operation',
#   'pk': 192,
#   'fields': {'date': '2022-05-24',
#    'operator': 3,
#    'note': 'Dual, atrazine, rd up to west 9 planter passes in Guri plot '}},
#  {'model': 'acrelog.operation',
#   'pk': 193,
#   'fields': {'date': '2022-05-24',
#    'operator': 2,
#    'note': '11 oz rup/ 11 oz extendimax'}},
#  {'model': 'acrelog.operation',
#   'pk': 194,
#   'fields': {'date': '2022-05-24', 'operator': 2, 'note': 'Blank for ma '}},
#  {'model': 'acrelog.operation',
#   'pk': 195,
#   'fields': {'date': '2022-05-24',
#    'operator': 3,
#    'note': 'Dual and round up'}},
#  {'model': 'acrelog.operation',
#   'pk': 196,
#   'fields': {'date': '2022-05-31', 'operator': 3, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 197,
#   'fields': {'date': '2022-05-31', 'operator': 3, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 198,
#   'fields': {'date': '2022-05-31', 'operator': 3, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 199,
#   'fields': {'date': '2022-05-31',
#    'operator': 3,
#    'note': 'Dekalb provided by Brian young '}},
#  {'model': 'acrelog.operation',
#   'pk': 200,
#   'fields': {'date': '2022-05-31',
#    'operator': 2,
#    'note': 'Roundup zidua solar panels '}},
#  {'model': 'acrelog.operation',
#   'pk': 201,
#   'fields': {'date': '2022-05-31', 'operator': 2, 'note': 'Sidedress'}},
#  {'model': 'acrelog.operation',
#   'pk': 202,
#   'fields': {'date': '2022-05-31', 'operator': 2, 'note': 'Sidedress'}},
#  {'model': 'acrelog.operation',
#   'pk': 203,
#   'fields': {'date': '2022-05-31', 'operator': 2, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 204,
#   'fields': {'date': '2022-05-31', 'operator': 2, 'note': 'Vyn plot'}},
#  {'model': 'acrelog.operation',
#   'pk': 205,
#   'fields': {'date': '2022-05-31', 'operator': 2, 'note': 'Vyn plot'}},
#  {'model': 'acrelog.operation',
#   'pk': 206,
#   'fields': {'date': '2022-05-31', 'operator': 2, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 207,
#   'fields': {'date': '2022-05-31',
#    'operator': 2,
#    'note': 'Not complete. 2/3 done '}},
#  {'model': 'acrelog.operation',
#   'pk': 208,
#   'fields': {'date': '2022-05-31',
#    'operator': 1,
#    'note': 'Valor 3oz @20 gal'}},
#  {'model': 'acrelog.operation',
#   'pk': 209,
#   'fields': {'date': '2022-05-31', 'operator': 1, 'note': 'Valor 3oz @20'}},
#  {'model': 'acrelog.operation',
#   'pk': 210,
#   'fields': {'date': '2022-05-31',
#    'operator': 1,
#    'note': 'Valor 3 oz @20 gal casteel/ma plot'}},
#  {'model': 'acrelog.operation',
#   'pk': 211,
#   'fields': {'date': '2022-05-31',
#    'operator': 1,
#    'note': 'Valor 3oz @20 gal roundup east end '}},
#  {'model': 'acrelog.operation',
#   'pk': 212,
#   'fields': {'date': '2022-05-31', 'operator': 1, 'note': 'Iso west end'}},
#  {'model': 'acrelog.operation',
#   'pk': 213,
#   'fields': {'date': '2022-05-31',
#    'operator': 1,
#    'note': 'Iso east end sorghum '}},
#  {'model': 'acrelog.operation',
#   'pk': 214,
#   'fields': {'date': '2022-05-31', 'operator': 1, 'note': 'West 2/3'}},
#  {'model': 'acrelog.operation',
#   'pk': 215,
#   'fields': {'date': '2022-05-31', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 216,
#   'fields': {'date': '2022-05-31',
#    'operator': 1,
#    'note': 'Quinn iso east end'}},
#  {'model': 'acrelog.operation',
#   'pk': 217,
#   'fields': {'date': '2022-05-31', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 218,
#   'fields': {'date': '2022-05-31', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 219,
#   'fields': {'date': '2022-05-31', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 220,
#   'fields': {'date': '2022-05-31', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 221,
#   'fields': {'date': '2022-05-31', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 222,
#   'fields': {'date': '2022-05-31',
#    'operator': 1,
#    'note': 'Torbert iso east end'}},
#  {'model': 'acrelog.operation',
#   'pk': 223,
#   'fields': {'date': '2022-05-31', 'operator': 1, 'note': 'Iso east end'}},
#  {'model': 'acrelog.operation',
#   'pk': 224,
#   'fields': {'date': '2022-05-31', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 225,
#   'fields': {'date': '2022-05-31', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 226,
#   'fields': {'date': '2022-05-31', 'operator': 1, 'note': 'Iso east end'}},
#  {'model': 'acrelog.operation',
#   'pk': 227,
#   'fields': {'date': '2022-05-31', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 228,
#   'fields': {'date': '2022-05-31', 'operator': 1, 'note': 'Iso east end'}},
#  {'model': 'acrelog.operation',
#   'pk': 229,
#   'fields': {'date': '2022-05-31', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 230,
#   'fields': {'date': '2022-06-01', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 231,
#   'fields': {'date': '2022-06-01', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 232,
#   'fields': {'date': '2022-06-01', 'operator': 1, 'note': '80 ft'}},
#  {'model': 'acrelog.operation',
#   'pk': 233,
#   'fields': {'date': '2022-06-01',
#    'operator': 1,
#    'note': 'Sprayed west half'}},
#  {'model': 'acrelog.operation',
#   'pk': 234,
#   'fields': {'date': '2022-06-01',
#    'operator': 4,
#    'note': 'ATS 7gpa\n13 starter\n24 28%'}},
#  {'model': 'acrelog.operation',
#   'pk': 235,
#   'fields': {'date': '2022-06-01', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 236,
#   'fields': {'date': '2022-06-01', 'operator': 1, 'note': 'Iso east end'}},
#  {'model': 'acrelog.operation',
#   'pk': 237,
#   'fields': {'date': '2022-06-01',
#    'operator': 2,
#    'note': 'Last 1/3 north side'}},
#  {'model': 'acrelog.operation',
#   'pk': 238,
#   'fields': {'date': '2022-06-01', 'operator': 2, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 239,
#   'fields': {'date': '2022-06-01', 'operator': 2, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 240,
#   'fields': {'date': '2022-06-01', 'operator': 2, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 241,
#   'fields': {'date': '2022-06-01', 'operator': 2, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 242,
#   'fields': {'date': '2022-06-01',
#    'operator': 2,
#    'note': '1.5 qt bicep  7ac sorghum'}},
#  {'model': 'acrelog.operation',
#   'pk': 243,
#   'fields': {'date': '2022-06-02',
#    'operator': 1,
#    'note': '22 ozRound up and 12 oz bicep'}},
#  {'model': 'acrelog.operation',
#   'pk': 244,
#   'fields': {'date': '2022-06-02', 'operator': 1, 'note': 'Valor 3oz ac '}},
#  {'model': 'acrelog.operation',
#   'pk': 245,
#   'fields': {'date': '2022-06-02', 'operator': 1, 'note': 'Valor 3 oz ac '}},
#  {'model': 'acrelog.operation',
#   'pk': 246,
#   'fields': {'date': '2022-06-02',
#    'operator': 1,
#    'note': 'Valor 3 oz ac on center fill in '}},
#  {'model': 'acrelog.operation',
#   'pk': 247,
#   'fields': {'date': '2022-06-02', 'operator': 2, 'note': 'Bordered field '}},
#  {'model': 'acrelog.operation',
#   'pk': 248,
#   'fields': {'date': '2022-06-02', 'operator': 2, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 249,
#   'fields': {'date': '2022-06-02',
#    'operator': 2,
#    'note': '200 East has strips with ats applied at 44 gpa, all the rest 40 gpa straight 28'}},
#  {'model': 'acrelog.operation',
#   'pk': 250,
#   'fields': {'date': '2022-06-03', 'operator': 2, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 251,
#   'fields': {'date': '2022-06-03',
#    'operator': 2,
#    'note': 'Replant (spot 29.5 ac)'}},
#  {'model': 'acrelog.operation',
#   'pk': 252,
#   'fields': {'date': '2022-06-04', 'operator': 3, 'note': 'Plus zidua'}},
#  {'model': 'acrelog.operation',
#   'pk': 253,
#   'fields': {'date': '2022-06-04',
#    'operator': 3,
#    'note': '1/4 rate of prefix '}},
#  {'model': 'acrelog.operation',
#   'pk': 254,
#   'fields': {'date': '2022-06-04', 'operator': 1, 'note': 'R up fusillade '}},
#  {'model': 'acrelog.operation',
#   'pk': 255,
#   'fields': {'date': '2022-06-04',
#    'operator': 1,
#    'note': 'Round up fusillade '}},
#  {'model': 'acrelog.operation',
#   'pk': 256,
#   'fields': {'date': '2022-06-04', 'operator': 1, 'note': 'R up fusillade '}},
#  {'model': 'acrelog.operation',
#   'pk': 257,
#   'fields': {'date': '2022-06-04', 'operator': 1, 'note': 'R up fusillade '}},
#  {'model': 'acrelog.operation',
#   'pk': 258,
#   'fields': {'date': '2022-06-04', 'operator': 1, 'note': 'Left over seed'}},
#  {'model': 'acrelog.operation',
#   'pk': 259,
#   'fields': {'date': '2022-06-04', 'operator': 1, 'note': 'Left over seed'}},
#  {'model': 'acrelog.operation',
#   'pk': 260,
#   'fields': {'date': '2022-06-04',
#    'operator': 1,
#    'note': 'Left over seed. Fill on west end '}},
#  {'model': 'acrelog.operation',
#   'pk': 261,
#   'fields': {'date': '2022-06-04', 'operator': 1, 'note': 'Left over seed'}},
#  {'model': 'acrelog.operation',
#   'pk': 262,
#   'fields': {'date': '2022-06-04', 'operator': 1, 'note': 'Left over seed'}},
#  {'model': 'acrelog.operation',
#   'pk': 263,
#   'fields': {'date': '2022-06-03', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 264,
#   'fields': {'date': '2022-06-03', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 265,
#   'fields': {'date': '2022-06-03', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 266,
#   'fields': {'date': '2022-06-03', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 267,
#   'fields': {'date': '2022-06-03', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 268,
#   'fields': {'date': '2022-06-03', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 269,
#   'fields': {'date': '2022-06-03', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 270,
#   'fields': {'date': '2022-06-03', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 271,
#   'fields': {'date': '2022-06-03', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 272,
#   'fields': {'date': '2022-06-03', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 273,
#   'fields': {'date': '2022-06-03', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 274,
#   'fields': {'date': '2022-06-03', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 275,
#   'fields': {'date': '2022-06-03', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 276,
#   'fields': {'date': '2022-06-03', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 277,
#   'fields': {'date': '2022-06-03', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 278,
#   'fields': {'date': '2022-06-03', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 279,
#   'fields': {'date': '2022-06-03', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 280,
#   'fields': {'date': '2022-06-03', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 281,
#   'fields': {'date': '2022-06-03', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 282,
#   'fields': {'date': '2022-06-03', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 283,
#   'fields': {'date': '2022-06-03', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 284,
#   'fields': {'date': '2022-06-07', 'operator': 2, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 285,
#   'fields': {'date': '2022-06-07', 'operator': 2, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 286,
#   'fields': {'date': '2022-06-07', 'operator': 2, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 287,
#   'fields': {'date': '2022-06-07', 'operator': 2, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 288,
#   'fields': {'date': '2022-06-07', 'operator': 2, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 289,
#   'fields': {'date': '2022-06-07', 'operator': 2, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 290,
#   'fields': {'date': '2022-06-07', 'operator': 2, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 291,
#   'fields': {'date': '2022-06-07', 'operator': 2, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 292,
#   'fields': {'date': '2022-06-07', 'operator': 2, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 293,
#   'fields': {'date': '2022-06-07', 'operator': 2, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 294,
#   'fields': {'date': '2022-06-07', 'operator': 2, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 295,
#   'fields': {'date': '2022-06-07', 'operator': 3, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 296,
#   'fields': {'date': '2022-06-07', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 297,
#   'fields': {'date': '2022-06-07', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 298,
#   'fields': {'date': '2022-06-07', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 299,
#   'fields': {'date': '2022-06-07', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 300,
#   'fields': {'date': '2022-06-07', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 301,
#   'fields': {'date': '2022-06-07', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 302,
#   'fields': {'date': '2022-06-07', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 303,
#   'fields': {'date': '2022-06-07', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 304,
#   'fields': {'date': '2022-06-07', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 305,
#   'fields': {'date': '2022-06-07', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 306,
#   'fields': {'date': '2022-06-07', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 307,
#   'fields': {'date': '2022-06-07',
#    'operator': 1,
#    'note': 'Sprayed 154 acres sprayed east west started at north end working south'}},
#  {'model': 'acrelog.operation',
#   'pk': 308,
#   'fields': {'date': '2022-06-10',
#    'operator': 4,
#    'note': 'Roundup and Fusilade'}},
#  {'model': 'acrelog.operation',
#   'pk': 309,
#   'fields': {'date': '2022-06-09', 'operator': 2, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 310,
#   'fields': {'date': '2022-06-09', 'operator': 2, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 311,
#   'fields': {'date': '2022-06-09',
#    'operator': 2,
#    'note': 'North end rows, East pass ran out 3/4 way to the south end. Refer op center map'}},
#  {'model': 'acrelog.operation',
#   'pk': 312,
#   'fields': {'date': '2022-06-14', 'operator': 2, 'note': 'Incenerate/atz'}},
#  {'model': 'acrelog.operation',
#   'pk': 313,
#   'fields': {'date': '2022-06-16', 'operator': 2, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 314,
#   'fields': {'date': '2022-06-17',
#    'operator': 3,
#    'note': '28% 51 gallon\nATS 5.2 gallon\n'}},
#  {'model': 'acrelog.operation',
#   'pk': 315,
#   'fields': {'date': '2022-06-16', 'operator': 3, 'note': '28% 58 gallon'}},
#  {'model': 'acrelog.operation',
#   'pk': 316,
#   'fields': {'date': '2022-06-16', 'operator': 3, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 317,
#   'fields': {'date': '2022-06-20', 'operator': 3, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 318,
#   'fields': {'date': '2022-06-22', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 319,
#   'fields': {'date': '2022-06-22', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 320,
#   'fields': {'date': '2022-06-22', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 321,
#   'fields': {'date': '2022-06-22', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 322,
#   'fields': {'date': '2022-06-27',
#    'operator': 1,
#    'note': 'Side dress with DTC bar. Applied 50 gal'}},
#  {'model': 'acrelog.operation',
#   'pk': 323,
#   'fields': {'date': '2022-07-01', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 324,
#   'fields': {'date': '2022-07-01', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 325,
#   'fields': {'date': '2022-07-01', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 326,
#   'fields': {'date': '2022-07-06', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 327,
#   'fields': {'date': '2022-07-06', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 328,
#   'fields': {'date': '2022-07-06',
#    'operator': 3,
#    'note': '42oz rd up, section 3, zidua'}},
#  {'model': 'acrelog.operation',
#   'pk': 329,
#   'fields': {'date': '2022-07-07', 'operator': 1, 'note': 'Wheat harvest '}},
#  {'model': 'acrelog.operation',
#   'pk': 330,
#   'fields': {'date': '2022-07-07', 'operator': 1, 'note': 'Wheat harvest '}},
#  {'model': 'acrelog.operation',
#   'pk': 331,
#   'fields': {'date': '2022-07-07', 'operator': 1, 'note': 'Wheat harvest '}},
#  {'model': 'acrelog.operation',
#   'pk': 332,
#   'fields': {'date': '2022-07-11',
#    'operator': 1,
#    'note': 'Fusillade and zidua'}},
#  {'model': 'acrelog.operation',
#   'pk': 333,
#   'fields': {'date': '2022-07-11',
#    'operator': 1,
#    'note': 'Fusillade and zidua'}},
#  {'model': 'acrelog.operation',
#   'pk': 334,
#   'fields': {'date': '2022-07-11',
#    'operator': 1,
#    'note': '73w fusillade and zidua '}},
#  {'model': 'acrelog.operation',
#   'pk': 335,
#   'fields': {'date': '2022-07-13',
#    'operator': 3,
#    'note': 'Liberty. On west 2/3 of field '}},
#  {'model': 'acrelog.operation',
#   'pk': 336,
#   'fields': {'date': '2022-07-29',
#    'operator': 2,
#    'note': 'One swipe to clean out boom in center'}},
#  {'model': 'acrelog.operation',
#   'pk': 337,
#   'fields': {'date': '2022-07-28',
#    'operator': 2,
#    'note': 'One pass to clean out after spraying '}},
#  {'model': 'acrelog.operation',
#   'pk': 338,
#   'fields': {'date': '2022-09-07',
#    'operator': 2,
#    'note': 'Manganese \n2 qts/ac'}},
#  {'model': 'acrelog.operation',
#   'pk': 339,
#   'fields': {'date': '2022-09-21', 'operator': 3, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 340,
#   'fields': {'date': '2022-09-22', 'operator': 3, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 341,
#   'fields': {'date': '2022-09-26', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 342,
#   'fields': {'date': '2022-09-26',
#    'operator': 1,
#    'note': 'Picked end rows and south 6.2 acres '}},
#  {'model': 'acrelog.operation',
#   'pk': 343,
#   'fields': {'date': '2022-09-26', 'operator': 2, 'note': 'Vt 2660'}},
#  {'model': 'acrelog.operation',
#   'pk': 344,
#   'fields': {'date': '2022-09-23', 'operator': 2, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 345,
#   'fields': {'date': '2022-09-26', 'operator': 1, 'note': 'Soybeans '}},
#  {'model': 'acrelog.operation',
#   'pk': 346,
#   'fields': {'date': '2022-09-26', 'operator': 1, 'note': 'Soybeans'}},
#  {'model': 'acrelog.operation',
#   'pk': 347,
#   'fields': {'date': '2022-09-26', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 348,
#   'fields': {'date': '2022-09-26', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 349,
#   'fields': {'date': '2022-09-28', 'operator': 2, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 350,
#   'fields': {'date': '2022-09-28', 'operator': 2, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 351,
#   'fields': {'date': '2022-09-28', 'operator': 2, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 352,
#   'fields': {'date': '2022-09-29', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 353,
#   'fields': {'date': '2022-09-29', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 354,
#   'fields': {'date': '2022-09-29', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 355,
#   'fields': {'date': '2022-09-29', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 356,
#   'fields': {'date': '2022-09-30', 'operator': 3, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 357,
#   'fields': {'date': '2022-09-30', 'operator': 2, 'note': '12 angle 2deg'}},
#  {'model': 'acrelog.operation',
#   'pk': 358,
#   'fields': {'date': '2022-09-30',
#    'operator': 2,
#    'note': '6 angle, 2 degree. 7.8'}},
#  {'model': 'acrelog.operation',
#   'pk': 359,
#   'fields': {'date': '2022-10-03', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 360,
#   'fields': {'date': '2022-10-03', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 361,
#   'fields': {'date': '2022-10-03', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 362,
#   'fields': {'date': '2022-10-04', 'operator': 3, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 363,
#   'fields': {'date': '2022-10-05', 'operator': 3, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 364,
#   'fields': {'date': '2022-10-05', 'operator': 2, 'note': 'East 20 ac'}},
#  {'model': 'acrelog.operation',
#   'pk': 365,
#   'fields': {'date': '2022-10-05', 'operator': 2, 'note': '60 ac '}},
#  {'model': 'acrelog.operation',
#   'pk': 366,
#   'fields': {'date': '2022-10-08', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 367,
#   'fields': {'date': '2022-10-10', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 368,
#   'fields': {'date': '2022-10-10', 'operator': 4, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 369,
#   'fields': {'date': '2022-10-10', 'operator': 4, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 370,
#   'fields': {'date': '2022-10-14', 'operator': 4, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 371,
#   'fields': {'date': '2022-10-14', 'operator': 4, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 372,
#   'fields': {'date': '2022-10-14', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 373,
#   'fields': {'date': '2022-10-16', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 374,
#   'fields': {'date': '2022-10-20', 'operator': 2, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 375,
#   'fields': {'date': '2022-10-24', 'operator': 1, 'note': 'Cleaned off'}},
#  {'model': 'acrelog.operation',
#   'pk': 376,
#   'fields': {'date': '2022-10-24', 'operator': 1, 'note': 'Cleaned off'}},
#  {'model': 'acrelog.operation',
#   'pk': 377,
#   'fields': {'date': '2022-10-24', 'operator': 1, 'note': 'Cleaned off'}},
#  {'model': 'acrelog.operation',
#   'pk': 378,
#   'fields': {'date': '2022-10-24', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 379,
#   'fields': {'date': '2022-11-04', 'operator': 1, 'note': 'Cleaned off\n'}},
#  {'model': 'acrelog.operation',
#   'pk': 380,
#   'fields': {'date': '2022-11-04', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 381,
#   'fields': {'date': '2022-11-04', 'operator': 2, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 382,
#   'fields': {'date': '2022-11-04', 'operator': 2, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 383,
#   'fields': {'date': '2022-11-07',
#    'operator': 1,
#    'note': 'Picked corn around sorghum '}},
#  {'model': 'acrelog.operation',
#   'pk': 384,
#   'fields': {'date': '2022-11-07',
#    'operator': 1,
#    'note': 'Picked corn around sorghum iso'}},
#  {'model': 'acrelog.operation',
#   'pk': 385,
#   'fields': {'date': '2022-11-07',
#    'operator': 1,
#    'note': 'Picked corn iso on east end'}},
#  {'model': 'acrelog.operation',
#   'pk': 386,
#   'fields': {'date': '2022-11-07',
#    'operator': 1,
#    'note': 'Picked corn around sorghum iso'}},
#  {'model': 'acrelog.operation',
#   'pk': 387,
#   'fields': {'date': '2022-11-08', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 388,
#   'fields': {'date': '2022-11-10', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 389,
#   'fields': {'date': '2022-11-10', 'operator': 1, 'note': 'Corn plots '}},
#  {'model': 'acrelog.operation',
#   'pk': 390,
#   'fields': {'date': '2022-11-23', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 391,
#   'fields': {'date': '2022-11-23', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 392,
#   'fields': {'date': '2022-11-23', 'operator': 1, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 393,
#   'fields': {'date': '2022-12-07', 'operator': 2, 'note': nan}},
#  {'model': 'acrelog.operation',
#   'pk': 394,
#   'fields': {'date': '2022-12-08',
#    'operator': 5,
#    'note': 'VRF Map avg 204 lbs /ac\nVRF Potash avg 275 lbs/ac'}},
#  {'model': 'acrelog.operation',
#   'pk': 395,
#   'fields': {'date': '2022-12-08',
#    'operator': 5,
#    'note': 'VRF Map  242 lbs/ac\nPotash: 240 lbs/ac'}},
#  {'model': 'acrelog.operation',
#   'pk': 396,
#   'fields': {'date': '2022-12-08',
#    'operator': 5,
#    'note': 'VRF MAP: 285 lbs.ac\nPotash: 240 lbs/ac'}},
#  {'model': 'acrelog.operation',
#   'pk': 397,
#   'fields': {'date': '2022-12-08',
#    'operator': 5,
#    'note': 'VRF MAP: 300 lbs/ac\nPotash: 240 lbs/ac'}},
#  {'model': 'acrelog.operation',
#   'pk': 398,
#   'fields': {'date': '2022-12-08',
#    'operator': 5,
#    'note': 'VRF MAP: 266 lbs/ac\nVRF Potash: 252 lb/ac'}},
#  {'model': 'acrelog.operation',
#   'pk': 399,
#   'fields': {'date': '2022-12-08',
#    'operator': 5,
#    'note': 'VRF MAP: 177 lbs/ac\nVRF Potash: 266 lbs/ac'}},
#  {'model': 'acrelog.operation',
#   'pk': 400,
#   'fields': {'date': '2022-12-08',
#    'operator': 5,
#    'note': 'VRF MAP: 292 lb/ac\nVRF Potash: 240 lbs/ac'}},
#  {'model': 'acrelog.operation',
#   'pk': 401,
#   'fields': {'date': '2022-12-08',
#    'operator': 5,
#    'note': 'VRF MAP: 180 lbs/ac\nVRF Potash: 131 lbs/ac'}},
#  {'model': 'acrelog.operation',
#   'pk': 402,
#   'fields': {'date': '2022-12-08',
#    'operator': 5,
#    'note': 'VRF MAP: 268 lbs/ac\nVRF Potash: 78 lbs/ac'}},
#  {'model': 'acrelog.operation',
#   'pk': 403,
#   'fields': {'date': '2022-12-08',
#    'operator': 5,
#    'note': 'Potash: 260 lbs/ac'}},
#  {'model': 'acrelog.operation',
#   'pk': 404,
#   'fields': {'date': '2022-12-08', 'operator': 5, 'note': '240 lbs/ ac'}},
#  {'model': 'acrelog.operation',
#   'pk': 405,
#   'fields': {'date': '2022-12-08',
#    'operator': 5,
#    'note': 'VRF MAP: 294 lb/ac\nVRF Potash: 170 lb/ac'}},
#  {'model': 'acrelog.operation',
#   'pk': 406,
#   'fields': {'date': '2022-12-08', 'operator': 5, 'note': '240 lbs/ac'}},
#  {'model': 'acrelog.operation',
#   'pk': 407,
#   'fields': {'date': '2022-12-08', 'operator': 5, 'note': '260 lb/ac'}},
#  {'model': 'acrelog.operation',
#   'pk': 408,
#   'fields': {'date': '2022-12-08', 'operator': 5, 'note': '240 lb/ac'}},
#  {'model': 'acrelog.operation',
#   'pk': 409,
#   'fields': {'date': '2022-12-08',
#    'operator': 5,
#    'note': 'MAP: 260 lb/ac\nPotash: 240 lb/ac'}},
#  {'model': 'acrelog.operation',
#   'pk': 410,
#   'fields': {'date': '2022-12-08',
#    'operator': 5,
#    'note': 'VRF MAP: 270 lb/ac\nVRF Potash: 240 lb/ac'}},
#  {'model': 'acrelog.operation',
#   'pk': 411,
#   'fields': {'date': '2022-12-08',
#    'operator': 5,
#    'note': 'VRF Map: 255 lb/ac\nVRF Potash: 265 lb/ac'}},
#  {'model': 'acrelog.operation',
#   'pk': 412,
#   'fields': {'date': '2022-11-22',
#    'operator': 5,
#    'note': 'VRA Lime\nAvg: .9 tn/ac'}},
#  {'model': 'acrelog.operation',
#   'pk': 413,
#   'fields': {'date': '2022-11-22',
#    'operator': 5,
#    'note': 'VRA Average rate: 1.2 tn/ac'}},
#  {'model': 'acrelog.operation',
#   'pk': 414,
#   'fields': {'date': '2022-11-17',
#    'operator': 5,
#    'note': 'VRF MAP Avg: 255 lbs/ac\nVRF Potash Avg: 242 lbs/ac'}},
#  {'model': 'acrelog.operation',
#   'pk': 415,
#   'fields': {'date': '2022-11-17',
#    'operator': 5,
#    'note': 'VRF MAP: 255 lbs/ac\nVRF Potash: 288 lbs/ac'}},
#  {'model': 'acrelog.operation',
#   'pk': 416,
#   'fields': {'date': '2022-11-17',
#    'operator': 5,
#    'note': 'VRF MAP: 252 lbs/ac\nVRF Potash: 262 lbs/ac'}},
#  {'model': 'acrelog.operation',
#   'pk': 417,
#   'fields': {'date': '2022-11-17',
#    'operator': 5,
#    'note': 'VRF MAP: 283 lbs/ac\nVRF Potash: 284 lbs/ac'}},
#  {'model': 'acrelog.operation',
#   'pk': 418,
#   'fields': {'date': '2022-11-17',
#    'operator': 5,
#    'note': 'VRF MAP: 264 lb/ac\nVRF Potash: 155 lb/ac'}},
#  {'model': 'acrelog.operation',
#   'pk': 419,
#   'fields': {'date': '2022-11-17',
#    'operator': 5,
#    'note': 'VRF MAP: 266 lbs/ac\nVRF Potash: 249 lbs/ac'}},
#  {'model': 'acrelog.operation',
#   'pk': 420,
#   'fields': {'date': '2022-11-17',
#    'operator': 5,
#    'note': 'MAP: 250 lbs/ac\nVRF Potash: 265 lbs/ac'}},
#  {'model': 'acrelog.operation',
#   'pk': 421,
#   'fields': {'date': '2022-11-17',
#    'operator': 5,
#    'note': 'VRF MAP: 257 lbs/ac\nVRF Potash: 253 lbs/ac'}},
#  {'model': 'acrelog.operation',
#   'pk': 422,
#   'fields': {'date': '2022-11-17',
#    'operator': 5,
#    'note': 'VRF MAP: 264 lbs/ac\nVRF Potash: 180 lbs/ac'}},
#  {'model': 'acrelog.operation',
#   'pk': 423,
#   'fields': {'date': '2022-11-17',
#    'operator': 5,
#    'note': 'VRF MAP: 212 lbs/ac\nVRF Potash: 249 lbs/ac'}},
#  {'model': 'acrelog.operation',
#   'pk': 424,
#   'fields': {'date': '2022-11-17',
#    'operator': 5,
#    'note': 'VRF MAP: 142 lbs/ac\nVRF Potash: 268 lbs/ac'}},
#  {'model': 'acrelog.operation',
#   'pk': 425,
#   'fields': {'date': '2022-11-17',
#    'operator': 5,
#    'note': 'VRF MAP: 223 lbs/ac\nVRF Potash: 85 lbs/ac'}},
#  {'model': 'acrelog.operation',
#   'pk': 426,
#   'fields': {'date': '2022-11-17', 'operator': 5, 'note': 'VRF: 185 lbs/ac'}},
#  {'model': 'acrelog.operation',
#   'pk': 427,
#   'fields': {'date': '2022-11-17',
#    'operator': 5,
#    'note': 'VRF MAP: 284 lbs/ac'}},
#  {'model': 'acrelog.operation',
#   'pk': 428,
#   'fields': {'date': '2022-11-17',
#    'operator': 5,
#    'note': 'VRF MAP: 279 lbs/ac'}},
#  {'model': 'acrelog.operation',
#   'pk': 429,
#   'fields': {'date': '2022-11-17',
#    'operator': 5,
#    'note': 'VRF MAP: 153 lbs/ac\nVRF Potash: 133 lbs/ac'}},
#  {'model': 'acrelog.operation',
#   'pk': 430,
#   'fields': {'date': '2022-11-17',
#    'operator': 5,
#    'note': 'VRF MAP: 139 lbs/ac\nVRF Potash: 121 lbs/ac'}},
#  {'model': 'acrelog.operation',
#   'pk': 431,
#   'fields': {'date': '2022-11-17',
#    'operator': 5,
#    'note': 'VRF MAP: 154 lbs/ac'}},
#  {'model': 'acrelog.operation',
#   'pk': 432,
#   'fields': {'date': '2022-11-17',
#    'operator': 5,
#    'note': 'VRF MAP: 115.8 lbs/ac'}},
#  {'model': 'acrelog.operation',
#   'pk': 433,
#   'fields': {'date': '2022-11-17',
#    'operator': 5,
#    'note': 'MAP: 240 lbs/ac\nPotash: 225 lbs/ac'}}]

# %% [markdown]
# You can dump the dictionary to JSON then load the JSON file to the database.
